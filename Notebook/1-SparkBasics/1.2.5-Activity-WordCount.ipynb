// %% [markdown]
// # Activity - Word Count
//
// Task: Count up how many of each word appears in a book.

// %%
spark
// Out:
// Intitializing Scala interpreter ...
// Spark Web UI available at http://192.168.1.19:4040
// SparkContext available as 'sc' (version = 2.4.5, master = local[*], app id = local-1588896969708)
// SparkSession available as 'spark'
// res0: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@407eaa0e

// %% [markdown]
// # Method 1: Simplest Approach

// %%
val book = sc.textFile("../../data/book.txt")
// Out:
// book: org.apache.spark.rdd.RDD[String] = ../../data/book.txt MapPartitionsRDD[1] at textFile at <console>:25

// %% [markdown]
// Split into words separated by a space character

// %%
val words = book.flatMap(_.split(" "))
// Out:
// words: org.apache.spark.rdd.RDD[String] = MapPartitionsRDD[5] at flatMap at <console>:26

// %% [markdown]
// Count up the occurences of each word with `countByValue`

// %%
val wordCounts = words.countByValue()
// Out:
// wordCounts: scala.collection.Map[String,Long] = Map(foolproof -> 1, precious -> 1, inflammatory -> 1, referrer, -> 1, hourly -> 3, embedded -> 1, way). -> 1, touch, -> 1, of. -> 3, salesperson -> 5, Leeches -> 1, expansion. -> 1, rate -> 7, appropriate. -> 2, CPA?s -> 1, 2014 -> 2, WELL-MEANING -> 1, Talk -> 5, Much -> 1, Builder" -> 1, plugin -> 3, headache -> 1, purchasing -> 9, China" -> 1, looks -> 2, site, -> 7, ranking -> 2, scare -> 1, hard-earned -> 1, freedom? -> 1, Seattle, -> 3, PULLING -> 1, action. -> 1, accident -> 3, scale. -> 2, looking. -> 1, physically -> 1, 27, -> 1, call. -> 1, contracts -> 3, twofold. -> 1, scenario -> 1, Advertising -> 3, way? -> 2, nudge -> 1, gamble -> 1, ideas -> 19, sketches -> 1, static -> 1, freelancer. -> 1, ?PR:? -> 1, joining -> 1, particu...

// %% [markdown]
// Print the results

// %%
wordCounts.foreach(println)
// Out:
// (foolproof,1)
// (precious,1)
// (inflammatory,1)
// (referrer,,1)
// (hourly,3)
// (embedded,1)
// (way).,1)
// (touch,,1)
// (of.,3)
// (salesperson,5)
// (Leeches,1)
// (expansion.,1)
// (rate,7)
// (appropriate.,2)
// (CPA?s,1)
// (2014,2)
// (WELL-MEANING,1)
// (Talk,5)
// (Much,1)
// (Builder",1)
// (plugin,3)
// (headache,1)
// (purchasing,9)
// (China",1)
// (looks,2)
// (site,,7)
// (ranking,2)
// (scare,1)
// (hard-earned,1)
// (freedom?,1)
// (Seattle,,3)
// (PULLING,1)
// (action.,1)
// (accident,3)
// (scale.,2)
// (looking.,1)
// (physically,1)
// (27,,1)
// (call.,1)
// (contracts,3)
// (twofold.,1)
// (scenario,1)
// (Advertising,3)
// (way?,2)
// (nudge,1)
// (gamble,1)
// (ideas,19)
// (sketches,1)
// (static,1)
// (freelancer.,1)
// (?PR:?,1)
// (joining,1)
// (particularly,1)
// (used,15)
// (eye,3)
// (idea;,1)
// (striking,1)
// (paycheck.,1)
// (boss.,2)
// (competitor.,1)
// (automatic,2)
// (corporation.,1)
// (great.,2)
// (short-term,,1)
// (minimum.,3)
// ...

// %% [markdown]
// In this simple approach we see that the results contain words with punctuations, numbers, abbreviations, and the like. We can do a little better preprocessing using regular expressions.

// %% [markdown]
// # Method 2: Including Regular Expressions
//
// When using regular expressions in Scala, you start with `\\` follow by the expression.

// %%
val words = book.flatMap(_.split("\\W+"))  //Split by multiple words (W+)
// Out:
// words: org.apache.spark.rdd.RDD[String] = MapPartitionsRDD[9] at flatMap at <console>:26

// %% [markdown]
// As seen from our first results, we should also convert all words into lower cases so that there are no "double counts".

// %%
val lowerCaseWords = words.map(_.toLowerCase())
// Out:
// lowerCaseWords: org.apache.spark.rdd.RDD[String] = MapPartitionsRDD[10] at map at <console>:26

// %%
val wordCounts = lowerCaseWords.countByValue()
// Out:
// wordCounts: scala.collection.Map[String,Long] = Map(serious -> 1, foolproof -> 1, precious -> 2, inflammatory -> 1, hourly -> 3, embedded -> 1, salesperson -> 7, plentiful -> 1, rate -> 9, 2014 -> 8, plugin -> 3, headache -> 1, purchasing -> 9, ons -> 1, bing -> 1, looks -> 2, ranking -> 2, irs -> 3, california -> 2, scare -> 1, finalized -> 1, associations -> 1, accident -> 3, physically -> 2, conversations -> 1, contracts -> 4, scenario -> 1, nudge -> 2, gamble -> 4, ideas -> 27, sketches -> 1, static -> 1, oculus -> 5, unity -> 1, tweeted -> 1, joining -> 1, particularly -> 1, used -> 18, eye -> 3, striking -> 2, minority -> 1, automatic -> 2, widely -> 4, impressions -> 5, checklist -> 3, e -> 1, conversion -> 4, worded -> 1, unidirectional -> 1, significantly -> 4, beautiful -> 1, ...

// %%
wordCounts.foreach(println)
// Out:
// (serious,1)
// (foolproof,1)
// (precious,2)
// (inflammatory,1)
// (hourly,3)
// (embedded,1)
// (salesperson,7)
// (plentiful,1)
// (rate,9)
// (2014,8)
// (plugin,3)
// (headache,1)
// (purchasing,9)
// (ons,1)
// (bing,1)
// (looks,2)
// (ranking,2)
// (irs,3)
// (california,2)
// (scare,1)
// (finalized,1)
// (associations,1)
// (accident,3)
// (physically,2)
// (conversations,1)
// (contracts,4)
// (scenario,1)
// (nudge,2)
// (gamble,4)
// (ideas,27)
// (sketches,1)
// (static,1)
// (oculus,5)
// (unity,1)
// (tweeted,1)
// (joining,1)
// (particularly,1)
// (used,18)
// (eye,3)
// (striking,2)
// (minority,1)
// (automatic,2)
// (widely,4)
// (impressions,5)
// (checklist,3)
// (e,1)
// (conversion,4)
// (worded,1)
// (unidirectional,1)
// (significantly,4)
// (beautiful,1)
// (providing,6)
// (writing,15)
// (believing,1)
// (crawls,1)
// (launch,24)
// (explore,2)
// (tune,1)
// (killed,1)
// (acquisition,3)
// (lists,5)
// (down,21)
// (weird,4)
// (side,30)
// ...

// %% [markdown]
// For better presentation (and education!) let us sort the counts by most to least. We go back to `lowerCaseWords` and work from there.

// %%
val wordCounts = {lowerCaseWords.map(x=> (x,1)) // Map each word to a (word, 1) tuple
                                  .reduceByKey((x,y)=> x+y)
                   }
// Out:
// wordCounts: org.apache.spark.rdd.RDD[(String, Int)] = ShuffledRDD[20] at reduceByKey at <console>:27

// %%
val wordCountsSorted = {wordCounts.map(x=>(x._2, x._1))              // Swap to make (count, word) tuples
                                 .sortByKey(ascending=false)         // Sort the rdd by the counts in descending order
                       }
// Out:
// wordCountsSorted: org.apache.spark.rdd.RDD[(Int, String)] = ShuffledRDD[28] at sortByKey at <console>:26

// %%
for (result <- wordCountsSorted){
    val count = result._1
    val word = result._2
    println(s"$word: $count")
}
// Out:
// you: 1878
// to: 1828
// your: 1420
// the: 1292
// a: 1191
// of: 970
// and: 934
// that: 747
// it: 649
// in: 616
// is: 560
// for: 537
// on: 428
// are: 424
// if: 411
// s: 391
// i: 387
// business: 383
// can: 376
// be: 369
// as: 343
// have: 321
// with: 315
// t: 301
// this: 280
// or: 278
// time: 255
// but: 242
// they: 234
// will: 231
// what: 229
// at: 220
// my: 215
// re: 214
// do: 207
// not: 203
// about: 202
// more: 200
// product: 182
// an: 178
// up: 177
// need: 174
// them: 166
// from: 166
// how: 163
// there: 162
// out: 161
// new: 153
// people: 145
// work: 144
// so: 143
// just: 142
// own: 140
// all: 137
// don: 133
// : 125
// get: 123
// customers: 123
// want: 122
// their: 122
// company: 122
// by: 122
// some: 121
// ll: 114
// self: 111
// website: 109
// make: 108
// may: 107
// even: 104
// when: 102
// one: 100
// ve: 95
// than: 92
// also: 91
// much: 90
// job: 90
// who: 88
// money: 86
// was: 85
// these: 82
// find: 81
// ...
